# %%
import pandas as pd
import numpy as np
import torch
import os
from datasets import load_dataset
from transformers import pipeline
from dotenv import load_dotenv

# %%
load_dotenv()
device = "cuda" if torch.cuda.is_available() else "cpu"

pipe = pipeline("text-generation", model="openai-community/gpt2", token=os.getenv("HF_TOKEN"), device=device)
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]

# %%
responses = pipe('Do you know who Anthony Hopkins is?', max_length=2, num_return_sequences=3)

for response in responses:
    print(response['generated_text'])
# Out:
# [transformers] Passing `generation_config` together with generation-related arguments=({'num_return_sequences', 'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=2) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer GPT2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# Do you know who Anthony Hopkins is? think it's a good idea for me to be a female?" she asked.
#
# "Let's get to it," said I, looking down at my hands.
#
# "Not bad for a male," she said.
#
# I nodded. "I'm not going to worry about you. Just take a few minutes to get your panties out of your pants."
#
# A few minutes later the two of us had finished our work at the bar and were walking to our car. We had walked to the street, and I asked if I could see the street. I heard a voice from inside: "Let's get out of here."
#
# I turned to see a girl standing there with her hands covered in sweat.
#
# "What?" she said. "You're in the wrong place."
#
# "Yes," I told her.
#
# "Now what do you need?" she asked. "Do you need to take off your underwear?"
#
# I got up, and found a pair of shorts. "Just take them off. I'm gonna make you feel better. I know you don't want to do that. But how about we get back to work?"
#
# She said, "I'm gonna take off my underwear."
#
# Do you know who Anthony Hopkins is? know why you're still living with me?! I'm so happy I finally get to spend all this time with you! I'm really happy to be here with you, but I'm really worried that you're only going to make it to the end of this season. That wouldn't be so bad. And I know that you've been working hard at your school, but you're not going to be able to keep up with the other kids. You're going to be a burden. I mean, you're not going to be able to be around them much longer. And I'm really worried that you'll be sick. I'm really worried that you'll be able to survive forever. And I'm really worried that you are going to be the one that will give me all of this. And I'm really worried that I will never be able to feel love like you do. It's very hard to feel love like that. I'm really worried that I will never have the time to feel love like you do. I'm really worried that you will never be able to have the life that you are now. So I want you to get back to living with me. Just be happy.
#
# M: And you were telling me that you felt so much better
# Do you know who Anthony Hopkins is? need to call your police?
#
# Do you have any other questions?
#
# Have you ever been assaulted?
#
# What was your story about?
#
# If you have any questions, please let us know.
#
# We want to hear from you.
#
# If you have any questions about our police, please call us at 888-493-0846 or email us at info@lawfare.org.
#
# Check out our News Releases, Lawfare's Frequently Asked Questions, Lawfare's Lawyer Directory, and our Lawyer Directory for more information.

# %% [markdown]
# Option from the HF dataset author

# %%
splits = {'train': 'data/train-00000-of-00001.parquet', 'test': 'data/test-00000-of-00001.parquet'}
df = pd.read_parquet("hf://datasets/davidquicast/constitucion-politica-del-peru-1993-qa/" + splits["train"])

# %%
df
# Out:
#                                                pregunta  \
# 0     Explique cómo se determinan los plazos de los ...
# 1     ¿Cuál es el alcance de las atribuciones del Co...
# 2     ¿Cuál es la jurisdicción temporal de los Conse...
# 3     En caso de impedimento temporal o permanente d...
# 4     ¿En qué casos el Congreso puede plantear una c...
# ...                                                 ...
# 1655  Detalle el proceso de cómputo de votos desde l...
# 1656  ¿Cuál es el alcance del artículo 85 en lo que ...
# 1657  ¿Cuál es el procedimiento público e ininterrum...
# 1658  ¿Es obligatorio que haya al menos un miembro d...
# 1659  ¿Cuáles son las responsabilidades de los gobie...
#
#                                               respuesta  \
# 0     De acuerdo con la Sexta Disposición Complement...
# 1     El artículo 94 de la Constitución Política del...
# 2     De acuerdo con la Constitución Política del Pe...
# 3     De acuerdo con el artículo 115 de la Constituc...
# 4     De acuerdo con el Artículo 132 de la Constituc...
# ...                                                 ...
# 1655  El proceso de cómputo de votos desde las mesas...
# 1656  El artículo 85 de la Constitución Política del...
# 1657  El artículo 185 de la Constitución Política de...
# 1658  No, la Constitución Política del Perú de 1993 ...
# 1659  De acuerdo con el Artículo 192 de la Constituc...
#
#                                                  fuente  \
# 0     Constitución Política del Perú 1993 - Sexta Di...
# 1     Constitución Política del Perú 1993 - Capítulo...
# 2     Constitución Política del Perú 1993 - Capitulo...
# 3     Constitución Política del Perú 1993 - Capítulo...
# 4     Constitución Política del Perú 1993 - Capítulo...
# ...                                                 ...
# 1655  Constitución Política del Perú 1993 - Capítulo...
# 1656  Constitución Política del Perú 1993 - Capítulo...
# 1657  Constitución Política del Perú 1993 - Capítulo...
# 1658  Constitución Política del Perú 1993 - Capítulo...
# 1659  Constitución Política del Perú 1993 - Capítulo...
#
#                                                    tema
# 0     Servicios públicos; Educación; Conflictos soci...
# 1               Gobierno estructura; Servicios públicos
# 2     Servicios públicos; Gobierno y administración ...
# 3                          Gobierno; Servicios públicos
# 4               Gobierno estructura; Servicios públicos
# ...                                                 ...
# 1655            Servicios públicos; Seguridad ciudadana
# 1656    Servicios públicos; Prevención de la corrupción
# 1657            Servicios públicos; Seguridad ciudadana
# 1658                          Gobierno regional y local
# 1659  Servicios públicos; Prevención de la corrupció...
#
# [1660 rows x 4 columns]

# %% [markdown]
# Conventional way to load the dataset

# %%
peru_qa = load_dataset("davidquicast/constitucion-politica-del-peru-1993-qa", split="train")
# Out:
# README.md:   0%|          | 0.00/4.99k [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# data/train-00000-of-00001.parquet:   0%|          | 0.00/581k [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/145k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1660 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/415 [00:00<?, ? examples/s]

# %%
type(peru_qa)
# Out:
# datasets.arrow_dataset.Dataset
